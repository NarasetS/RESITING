# %% [markdown]
# # Build Investment-Ready SI with Existing and Committed Plant Exclusions
#
# Run this after `1_SI_Landcover.ipynb`. It masks the pre-feedstock landcover layer first, reruns the feedstock integration on the remaining cells, then reruns `11_SI_Farmarea.py` for the investment-ready final SI.

# %% [markdown]
# ## Step 1: Import the investment-ready builder

# %%
from pathlib import Path
import runpy

module = runpy.run_path('11a_SI_ApplyPlantExclusions.py')
build_existing_committed_cutoff_si = module['build_existing_committed_cutoff_si']

# %% [markdown]
# ## Step 2: Exclude sites, rerun feedstock, then rerun final SI

# %%
build_existing_committed_cutoff_si(
    template_path=Path('Output') / 'xr_SI_Landcover_beforefeedstock.nc',
    cutoff_prefeedstock_path=Path('Output') / 'xr_SI_Landcover_beforefeedstock_existing_committed_cutoff.nc',
    cutoff_landcover_path=Path('Output') / 'xr_SI_Landcover_existing_committed_cutoff.nc',
    output_path=Path('Output') / 'xr_final_SI_all_existing_committed_cutoff.nc',
    farmarea_output_path=Path('Output') / 'xr_SI_Farmarea_existing_committed_cutoff.nc',
    weight_source='empirical',  # options: 'default', 'empirical'
    buffer_m=2900,
)
# Out:
# Building investment-ready SI with existing/committed sites excluded before feedstock integration...
# Loading existing power plants and committed RE sites...
# Existing power plants: 1184
# Committed RE sites: 175
# Total restricted sites: 1359
# Checking final SI grid cells against restricted sites...
# Masking 250619 pre-feedstock grid cells across 8 variables...
# Saving pre-feedstock cutoff landcover SI to Output\xr_SI_Landcover_beforefeedstock_existing_committed_cutoff.nc...
# Loading pre-feedstock landcover SI from Output\xr_SI_Landcover_beforefeedstock_existing_committed_cutoff.nc...
# Loading Thailand provincial boundaries...
# Loaded 77 provinces
# Assigning grid points to provinces...
# 1_1_SI_Landcover_feedstock.py:51: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   prov_centroids = np.column_stack((thailandmap.geometry.centroid.x, thailandmap.geometry.centroid.y))
# Assigned 15957810 points in 22.67s
# Loaded feedstock: 231 records | 77 provinces
# Distributing feedstock potential...
#   A_Biomass: Distributed to 77 provinces
#   A_BGEC: Distributed to 77 provinces
#   A_BGWW: Distributed to 77 provinces
#   A_MSW: Distributed to 72 provinces
#   A_IEW: Distributed to 72 provinces
#   A_BGEC: 1840.17 ktoe
#   A_Biomass: 38369.03 ktoe
#   A_BGWW: 1840.17 ktoe
#   A_MSW: 6805.07 ktoe
#   A_IEW: 6805.07 ktoe
# Saving feedstock-integrated landcover SI to Output\xr_SI_Landcover_existing_committed_cutoff.nc...
# Feedstock integration completed.
# Starting Farm Area Suitability Processing (existing/committed cutoff)...
# Loading empirical weights from weightfactors\empirical_weights.json...
#   -> Applied empirical weights for Wind
#   -> Wind: Landcover: 0.0418, Slope: 0.0305, Elevation: 0.1202, Distance to settlement: 0.1061, Distance to wetland: 0.0471, Distance to forest: 0.0070, Distance to road: 0.0383, Distance to substation: 0.1252, Resource potential: 0.3430, Land cost: 0.1407, Farm/feedstock area: 0.0000
#   -> Applied empirical weights for Solar
#   -> Solar: Landcover: 0.0386, Slope: 0.1393, Elevation: 0.0808, Distance to settlement: 0.1464, Distance to wetland: 0.0230, Distance to forest: 0.0184, Distance to road: 0.0125, Distance to substation: 0.2206, Resource potential: 0.1627, Land cost: 0.1577, Farm/feedstock area: 0.0000
#   -> Applied empirical weights for Biomass
#   -> Biomass: Landcover: 0.0351, Slope: 0.1432, Elevation: 0.1441, Distance to settlement: 0.0120, Distance to wetland: 0.0102, Distance to forest: 0.0000, Distance to road: 0.0189, Distance to substation: 0.3511, Resource potential: 0.0000, Land cost: 0.2854, Farm/feedstock area: 0.0000
#   -> Applied empirical weights for BGEC
#   -> BGEC: Landcover: 0.0320, Slope: 0.1347, Elevation: 0.1738, Distance to settlement: 0.0131, Distance to wetland: 0.0151, Distance to forest: 0.0000, Distance to road: 0.0221, Distance to substation: 0.2957, Resource potential: 0.0000, Land cost: 0.3136, Farm/feedstock area: 0.0000
#   -> Applied empirical weights for BGWW
#   -> BGWW: Landcover: 0.0320, Slope: 0.1347, Elevation: 0.1738, Distance to settlement: 0.0131, Distance to wetland: 0.0151, Distance to forest: 0.0000, Distance to road: 0.0221, Distance to substation: 0.2957, Resource potential: 0.0000, Land cost: 0.3136, Farm/feedstock area: 0.0000
#   -> Applied empirical weights for MSW
#   -> MSW: Landcover: 0.0203, Slope: 0.0661, Elevation: 0.1947, Distance to settlement: 0.1007, Distance to wetland: 0.0445, Distance to forest: 0.0000, Distance to road: 0.1055, Distance to substation: 0.2266, Resource potential: 0.0000, Land cost: 0.2415, Farm/feedstock area: 0.0000
#   -> Applied empirical weights for IEW
#   -> IEW: Landcover: 0.0203, Slope: 0.0661, Elevation: 0.1947, Distance to settlement: 0.1007, Distance to wetland: 0.0445, Distance to forest: 0.0000, Distance to road: 0.1055, Distance to substation: 0.2266, Resource potential: 0.0000, Land cost: 0.2415, Farm/feedstock area: 0.0000
# Processing Step 0: Landcover & Template Setup...
# Processing Step 1: xr_SI_Slope.nc...
# Processing Step 2: xr_SI_Elevation.nc...
# Processing Step 3: xr_SI_Distancetosettlementarea.nc...
# Processing Step 4: xr_SI_Distancetowetland.nc...
# Processing Step 5: xr_SI_Distancetoforest.nc...
# Processing Step 6: xr_SI_Distancetoroad.nc...
# Processing Step 7: xr_SI_Distancetosubstation.nc...
# Processing Step 8: xr_SI_resourcepotential.nc...
# Processing Step 9: xr_SI_LandCost.nc...
# Processing Step 10: Farm Area for Wind and Solar...
# Processing Step 10: Feedstock Area for Bio/Waste plants...
# Saving Farm Area SI to Output\xr_SI_Farmarea_existing_committed_cutoff.nc...
#
# --- Processing Summary ---
# Wind    -> Max SI: 2.7347 | Sum AVA: 61613.70
# Solar   -> Max SI: 2.7783 | Sum AVA: 63845.62
# Biomass -> Max SI: 2.9136 | Sum AVA: 77109.27 | Sum Cap: 14540.18 MW
# BGEC    -> Max SI: 2.9073 | Sum AVA: 77109.27 | Sum Cap: 1195.93 MW
# BGWW    -> Max SI: 2.9073 | Sum AVA: 77109.27 | Sum Cap: 1195.93 MW
# MSW     -> Max SI: 2.9301 | Sum AVA: 77307.89 | Sum Cap: 4718.15 MW
# IEW     -> Max SI: 2.9301 | Sum AVA: 77307.89 | Sum Cap: 2965.70 MW
#
# Saving final processed dataset to Output\xr_final_SI_all_existing_committed_cutoff.nc...
# Successfully saved final dataset.
# Investment-ready existing/committed cutoff SI completed.
